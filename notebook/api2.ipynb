# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
endpoint = 'https://data.nashville.gov/resource/7qhx-rexh.json'

# %%
response = requests.get(endpoint)

# %%
response
# Out:
# <Response [200]>

# %%
result = response.json()
result
# Out:
# [{'case_number': '966190',
#   'status': 'Closed',
#   'case_request': 'Resolved by hubNashville on First Call',
#   'case_subrequest': 'Resolved by hubNashville on First Call',
#   'additional_subrequest': 'Resolved by hubNashville on First Call',
#   'date_time_opened': '2022-05-04T17:54:30.000',
#   'date_time_closed': '2022-05-04T17:54:30.000',
#   'case_origin': 'Phone',
#   'state_issue': 'False',
#   'closed_when_created': 'True',
#   'incident_address': '1301 Pilgrim Dr',
#   'incident_city': 'MADISON',
#   'incident_council_district': '8',
#   'incident_zip_code': '37115',
#   'latitude': '36.2718801',
#   'longitude': '-86.7175492',
#   'mapped_location': {'latitude': '36.2718801', 'longitude': '-86.7175492'},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '3',
#   ':@computed_region_gxvr_9jxz': '12',
#   ':@computed_region_yf9r_ed6g': '3',
#   ':@computed_region_fvtq_wnma': '26',
# ...

# %%
len(result)
# Out:
# 1000

# %%
endpoint = 'https://data.nashville.gov/resource/7qhx-rexh.json'

params = {
    'case_origin': 'Phone'
    
}

result = requests.get(endpoint, params = params)

result.text
# Out:
# '[{"case_number":"966190","status":"Closed","case_request":"Resolved by hubNashville on First Call","case_subrequest":"Resolved by hubNashville on First Call","additional_subrequest":"Resolved by hubNashville on First Call","date_time_opened":"2022-05-04T17:54:30.000","date_time_closed":"2022-05-04T17:54:30.000","case_origin":"Phone","state_issue":"False","closed_when_created":"True","incident_address":"1301 Pilgrim Dr","incident_city":"MADISON","incident_council_district":"8","incident_zip_code":"37115","latitude":"36.2718801","longitude":"-86.7175492","mapped_location":{"latitude":"36.2718801","longitude":"-86.7175492"}}\n,{"case_number":"932934","status":"Closed","case_request":"Public Safety","case_subrequest":"Abandoned Vehicles","additional_subrequest":"Abandoned Vehicles","date_time_opened":"2022-04-01T21:01:39.000","date_time_closed":"2022-04-05T11:29:54.000","case_origin":"Phone","state_issue":"False","closed_when_created":"False","incident_address":"1237 Tuckahoe Dr","incid
# ...

# %%
result = pd.DataFrame(result.json())
result
# Out:
#     case_number  status                            case_request  \
# 0        966190  Closed  Resolved by hubNashville on First Call
# 1        932934  Closed                           Public Safety
# 2        932939  Closed               Trash, Recycling & Litter
# 3        932935  Closed  Resolved by hubNashville on First Call
# 4        932938  Closed                           Public Safety
# ..          ...     ...                                     ...
# 995      693738  Closed  Resolved by hubNashville on First Call
# 996     1032740  Closed                           Public Safety
# 997      694929  Closed  Resolved by hubNashville on First Call
# 998      693454  Closed  Resolved by hubNashville on First Call
# 999      696490  Closed  Resolved by hubNashville on First Call
#
#                              case_subrequest  \
# 0     Resolved by hubNashville on First Call
# 1                         Abandoned Vehicles
# 2                               Cart Service
# ...

# %%
endpoint = 'https://data.nashville.gov/resource/7qhx-rexh.json'

params = {
    'status': 'Closed'
    
}

result2 = requests.get(endpoint, params = params)

result2.text
# Out:
# '[{"case_number":"966190","status":"Closed","case_request":"Resolved by hubNashville on First Call","case_subrequest":"Resolved by hubNashville on First Call","additional_subrequest":"Resolved by hubNashville on First Call","date_time_opened":"2022-05-04T17:54:30.000","date_time_closed":"2022-05-04T17:54:30.000","case_origin":"Phone","state_issue":"False","closed_when_created":"True","incident_address":"1301 Pilgrim Dr","incident_city":"MADISON","incident_council_district":"8","incident_zip_code":"37115","latitude":"36.2718801","longitude":"-86.7175492","mapped_location":{"latitude":"36.2718801","longitude":"-86.7175492"}}\n,{"case_number":"932934","status":"Closed","case_request":"Public Safety","case_subrequest":"Abandoned Vehicles","additional_subrequest":"Abandoned Vehicles","date_time_opened":"2022-04-01T21:01:39.000","date_time_closed":"2022-04-05T11:29:54.000","case_origin":"Phone","state_issue":"False","closed_when_created":"False","incident_address":"1237 Tuckahoe Dr","incid
# ...

# %%
result2 = pd.DataFrame(result2.json())
result2
# Out:
#     case_number  status                            case_request  \
# 0        966190  Closed  Resolved by hubNashville on First Call
# 1        932934  Closed                           Public Safety
# 2        932939  Closed               Trash, Recycling & Litter
# 3        932935  Closed  Resolved by hubNashville on First Call
# 4        932938  Closed                           Public Safety
# ..          ...     ...                                     ...
# 995      811211  Closed  Resolved by hubNashville on First Call
# 996      811213  Closed               Trash, Recycling & Litter
# 997     1078122  Closed               Trash, Recycling & Litter
# 998      700878  Closed               Trash, Recycling & Litter
# 999      706469  Closed               Trash, Recycling & Litter
#
#                              case_subrequest  \
# 0     Resolved by hubNashville on First Call
# 1                         Abandoned Vehicles
# 2                               Cart Service
# ...

# %%
endpoint = 'https://data.nashville.gov/resource/7qhx-rexh.json'

params = {
    'incident_city': 'NASHVILLE'
    
}

result3 = requests.get(endpoint, params = params)

result3.text
# Out:
# '[{"case_number":"932934","status":"Closed","case_request":"Public Safety","case_subrequest":"Abandoned Vehicles","additional_subrequest":"Abandoned Vehicles","date_time_opened":"2022-04-01T21:01:39.000","date_time_closed":"2022-04-05T11:29:54.000","case_origin":"Phone","state_issue":"False","closed_when_created":"False","incident_address":"1237 Tuckahoe Dr","incident_city":"NASHVILLE","incident_council_district":"3","incident_zip_code":"37207","latitude":"36.25727","longitude":"-86.76369","mapped_location":{"latitude":"36.25727","longitude":"-86.76369"}}\n,{"case_number":"932938","status":"Closed","case_request":"Public Safety","case_subrequest":"Request Non-Emergency Police Assistance","date_time_opened":"2022-04-01T21:03:10.000","date_time_closed":"2022-04-01T22:04:31.000","case_origin":"Phone","state_issue":"False","closed_when_created":"False","incident_address":"401 Broadway","incident_city":"NASHVILLE","incident_council_district":"19","incident_zip_code":"37203","latitude":"36
# ...

# %%
result3 = pd.DataFrame(result3.json())
result3
# Out:
#     case_number  status                            case_request  \
# 0        932934  Closed                           Public Safety
# 1        932938  Closed                           Public Safety
# 2        932944  Closed  Resolved by hubNashville on First Call
# 3        794228  Closed                           Public Safety
# 4        965876  Closed                           Public Safety
# ..          ...     ...                                     ...
# 995      706695  Closed  Resolved by hubNashville on First Call
# 996      695670  Closed                           Public Safety
# 997      697985  Closed  Resolved by hubNashville on First Call
# 998      707383  Closed                     Property Violations
# 999      700272  Closed               Trash, Recycling & Litter
#
#                                        case_subrequest  \
# 0                                   Abandoned Vehicles
# 1              Request Non-Emergency Police Assistance
# ...

# %%
plt.bar(result3.incident_zip_code, result3.closed_when_created)
plt.xticks(rotation = 75);
